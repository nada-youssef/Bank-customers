# %%
import pandas as pd

# %%
customers = pd.read_csv(r'/content/Bank_Customer.csv')

# %%
customers.head()
# Out:
#     age           job  marital  education  balance duration
# 0  58.0    management  married   tertiary     2143      261
# 1  44.0    technician   single  secondary       29      151
# 2  33.0  entrepreneur  married  secondary        2       76
# 3  47.0   blue-collar  married    unknown     1506       92
# 4  33.0       unknown   single    unknown        1      198

# %%
customers.shape
# Out:
# (1090, 6)

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1090 entries, 0 to 1089
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        1000 non-null   float64
#  1   job        1090 non-null   object
#  2   marital    1090 non-null   object
#  3   education  1090 non-null   object
#  4   balance    1090 non-null   int64
#  5   duration   1090 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 51.2+ KB

# %%
customers.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1085    False
# 1086    False
# 1087    False
# 1088    False
# 1089    False
# Length: 1090, dtype: bool

# %%
customers.isna().sum()
# Out:
# age          90
# job           0
# marital       0
# education     0
# balance       0
# duration      0
# dtype: int64

# %%
customers.dropna(axis = 'index', how='any',subset = ['age'], inplace = True)

# %%
customers.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# balance      0
# duration     0
# dtype: int64

# %%
customers['job'].unique()
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
customers['marital'].unique()
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
customers['education'].unique()
# Out:
# array(['tertiary', 'secondary', 'unknown', 'primary'], dtype=object)

# %%
customers['job'] = customers['job'].astype('string')
customers['marital'] = customers['marital'].astype('string')
customers['education'] = customers['education'].astype('string')

# %%
balance_group = customers.groupby(['balance'])

# %%
zero_balance= balance_group.get_group(0)

# %%
zero_balance['marital'].value_counts()
# Out:
# marital
# married     58
# single      25
# divorced     9
# Name: count, dtype: Int64

# %%
filt1 = (customers['balance'] < 0) & (customers['marital'] == 'married')

# %%
customers.loc[filt1]
# Out:
#       age            job  marital  education  balance duration
# 25   44.0         admin.  married  secondary     -372      172
# 36   25.0    blue-collar  married  secondary       -7      365
# 37   53.0     technician  married  secondary       -3     1666
# 46   58.0  self-employed  married   tertiary     -364      355
# 100  44.0    blue-collar  married  secondary     -674      257
# 112  56.0  self-employed  married    primary      -34      212
# 127  34.0       services  married  secondary      -16       78
# 150  51.0    blue-collar  married    unknown      -19      163
# 152  40.0     management  married   tertiary       -4     2033
# 210  38.0    blue-collar  married  secondary     -390      287
# 214  54.0    blue-collar  married    primary      -41      288
# 230  47.0    blue-collar  married    primary      -12       18
# 281  41.0         admin.  married  secondary      -62       55
# 315  46.0         admin.  married  secondary     -358      358
# ...

# %%
customers['age'].agg([min,max])
# Out:
# min    22.0
# max    61.0
# Name: age, dtype: float64

# %%
customers['duration']= pd.to_numeric(customers['duration'], errors='coerce')

# %%
filt2 = customers['duration'] > customers['duration'].median()
customers.loc[filt2,'job']
# Out:
# 0        management
# 6        management
# 7      entrepreneur
# 10           admin.
# 12       technician
#            ...
# 995     blue-collar
# 996          admin.
# 997     blue-collar
# 998        services
# 999      technician
# Name: job, Length: 495, dtype: string

# %%
customers.sort_values(by = 'duration', ascending = False)
# Out:
#       age          job   marital  education  balance  duration
# 152  40.0   management   married   tertiary       -4    2033.0
# 600  38.0  blue-collar   married  secondary      384    1906.0
# 59   46.0     services   married    primary      179    1778.0
# 474  34.0       admin.   married  secondary      869    1677.0
# 37   53.0   technician   married  secondary       -3    1666.0
# ..    ...          ...       ...        ...      ...       ...
# 550  42.0     services  divorced  secondary      372       NaN
# 660  32.0       admin.   married   tertiary      281       NaN
# 770  42.0     services   married  secondary        0       NaN
# 880  37.0     services   married  secondary       78       NaN
# 990  37.0   unemployed  divorced    primary      849       NaN
#
# [1000 rows x 6 columns]

# %%
customers.dropna(axis = 'index', how='any',inplace=True)
